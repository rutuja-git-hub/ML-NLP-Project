# %%
# Import training script
# !cp '/content/train_mlm.py' .
# Out:
# cp: '/content/train_mlm.py' and './train_mlm.py' are the same file

# %%
# Install Transformers library
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.4 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 596 kB 54.6 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 19.4 MB/s
# ...
#      |████████████████████████████████| 101 kB 12.0 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
import pandas as pd
import numpy as np

# %%
 #Import dataset
path = "/content/due_diligence.csv"
df_bonus = pd.read_csv(path)

# Convert dataframe to a list
df_as_list1 = df_bonus['Due Diligence Question or Request Description'].dropna()
df_as_list=df_as_list1.values.tolist()

# Flatten list for later use in encoding the sentences
flat_list = [x for xs in df_as_list for x in xs]
flat_list
df_as_list

# %%
# Continue training a pre-trained model by running MLM on dataset
# Replace distilbert-base-uncased with your own model
# !python train_mlm.py sentence-transformers/bert-base-nli-mean-tokens /content/due_diligence.csv
# Out:
# Downloading: 100% 625/625 [00:00<00:00, 614kB/s]
# Downloading: 100% 418M/418M [00:08<00:00, 52.4MB/s]
# Some weights of BertForMaskedLM were not initialized from the model checkpoint at sentence-transformers/bert-base-nli-mean-tokens and are newly initialized: ['cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading: 100% 399/399 [00:00<00:00, 335kB/s]
# Downloading: 100% 226k/226k [00:00<00:00, 2.91MB/s]
# Downloading: 100% 455k/455k [00:00<00:00, 6.10MB/s]
# Downloading: 100% 2.00/2.00 [00:00<00:00, 1.76kB/s]
# Downloading: 100% 112/112 [00:00<00:00, 124kB/s]
# Save checkpoints to: output/sentence-transformers_bert-base-nli-mean-tokens-2022-07-09_19-30-00
# Train sentences: 12909
# ...

# %%
# Import fine-tuning script
# !cp '/content/training_stsbenchmark.py' .
# Out:
# cp: '/content/training_stsbenchmark.py' and './training_stsbenchmark.py' are the same file

# %%
# Install Sentence Transformer library
# !pip install sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 85 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 27.0 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=50398ad188c3d1e0bd0e35f4b568d74fc394b8dd477c53a4cb4f56b1bdba24f0
#   Stored in directory: /root/.cache/pip/wheels/bf/06/fb/d59c1e5bd1dac7f6cf61ec0036cc3a10ab8fecaa6b2c3d3ee9
# Successfully built sentence-transformers
# ...

# %%
# Fine-tune pre-trained model on STS dataset
# !python training_stsbenchmark.py 'output/sentence-transformers_bert-base-nli-mean-tokens-2022-07-09_19-30-00'
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration:  39% 140/360 [00:20<00:32,  6.77it/s]
# Iteration:  39% 141/360 [00:20<00:32,  6.74it/s]
# Iteration:  39% 142/360 [00:20<00:32,  6.76it/s]
# Iteration:  40% 143/360 [00:20<00:31,  6.82it/s]
# Iteration:  40% 144/360 [00:20<00:31,  6.91it/s]
# Iteration:  40% 145/360 [00:20<00:30,  6.97it/s]
# Iteration:  41% 146/360 [00:20<00:30,  6.94it/s]
# Iteration:  41% 147/360 [00:20<00:30,  6.97it/s]
# Iteration:  41% 148/360 [00:21<00:30,  6.96it/s]
# Iteration:  41% 149/360 [00:21<00:30,  6.90it/s]
# Iteration:  42% 150/360 [00:21<00:30,  6.91it/s]
# Iteration:  42% 151/360 [00:21<00:30,  6.89it/s]
# Iteration:  42% 152/360 [00:21<00:30,  6.90it/s]
# Iteration:  42% 153/360 [00:21<00:29,  6.94it/s]
# Iteration:  43% 154/360 [00:22<00:29,  6.94it/s]
# Iteration:  43% 155/360 [00:22<00:29,  6.90it/s]
# Iteration:  43% 156/360 [00:22<00:29,  6.98it/s]
# Iteration:  44% 157/360 [00:22<00:29,  6.91it/s]
# ...

# %%
from sentence_transformers import SentenceTransformer

# %%
# Load newly created SentenceTransformer model
#model = SentenceTransformer('output/training_stsbenchmark_output-sentence-transformers_bert-base-nli-mean-tokens-2022-07-07_00-34-51-2022-07-07_01-06-00')
model = SentenceTransformer('output/training_stsbenchmark_output-sentence-transformers_bert-base-nli-mean-tokens-2022-07-09_19-30-00-2022-07-09_19-45-32')

# %%
# Encode dataset i.e. convert sentences to vectors
corpus_embeddings = model.encode(flat_list, show_progress_bar=True, convert_to_tensor=True)
# Out:
# Batches:   0%|          | 0/26416 [00:00<?, ?it/s]

# %%
# Function that searches the corpus (dataset) and prints the results
def search(inp_question):
    start_time = time.time()
    question_embedding = model.encode(inp_question, convert_to_tensor=True)
    hits = util.semantic_search(question_embedding, corpus_embeddings)
    end_time = time.time()
    hits = hits[0]  #Get the hits for the first query

    print("Input question:", inp_question)
    print("Results (after {:.3f} seconds):".format(end_time-start_time))
    print("Number of possible duplicates:", len(hits)) # Print the number of possible duplicates
    for hit in hits[0:50]:
        print("\t{:.3f}\t{}".format(hit['score'], flat_list[hit['corpus_id']]))

# %%
import time
from sentence_transformers import util

# %%
# Search for below questions in the dataset
print(
    search("provide professional biography for each member of the board")
    #search("Please provide the organizational structure as at the current date, indicating key employees and management"),
    #search("Please provide a copy of the most recent employee handbook."),
    #search("Review security documentation: A security charter or policy (to assess business correlation and maturity)."),
    #search("Copies of any Customer Support obligations, e.g. Service Level Agreements, outside of standard agreement."),
    #search("Copies of any audited financial statements, quarterly financial statements for last 4 quarters, and any other interim financial statements"),
    #search("List of real estate assets owned, leased or otherwise used by the Company, with an indication of the type of use (current and historical) of this real estate unit (shop, production plant, warehouse, office).")
)
# Out:
# Input question: provide professional biography for each member of the board
# Results (after 0.050 seconds):
# Number of possible duplicates: 10
# 	0.358	%
# 	0.358	%
# 	0.358	%
# 	0.358	%
# 	0.358	%
# 	0.358	%
# 	0.358	%
# 	0.358	%
# 	0.358	%
# 	0.358	%
# None

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
my_question = ["Please Provide an employee organization chart"]

# %%
my_question_vector= model.encode(my_question)
my_question_vector
# Out:
# array([[ 2.98299462e-01,  4.67688084e-01,  6.65377259e-01,
#         -3.20049793e-01,  6.41659141e-01,  4.01473612e-01,
#          9.65987965e-02,  3.17662835e-01, -4.54112589e-01,
#         -2.90934920e-01, -1.05772860e-01,  2.12294668e-01,
#         -1.70537233e-01,  4.59123015e-01, -5.39545834e-01,
#         -4.67298150e-01, -1.21590912e+00,  7.71893501e-01,
#         -2.80388594e-02, -8.30109298e-01,  7.95215294e-02,
#         -1.87270805e-01,  4.55481261e-01,  1.91641897e-02,
#         -1.68789938e-01,  1.39909312e-01, -1.49985582e-01,
#         -1.62001029e-01, -3.56504411e-01, -1.19342968e-01,
#         -1.63047880e-01, -7.70340145e-01,  2.55223453e-01,
#         -1.39400691e-01, -1.85448766e-01, -5.20474970e-01,
#          2.62281112e-02, -1.69609189e-02, -3.52809876e-02,
#         -2.20502973e-01, -7.22172081e-01, -6.61695227e-02,
#          1.54808253e-01,  1.44450235e+00, -1.72451898e-01,
#         -3.61167490e-01, -2.88469046e-01,  5.91593146e-01,
# ...

# %% [markdown]
# ###COMPARE

# %%
#sentences = list(df_as_list.iloc[:, 0])

# %%
sentences=df_as_list

# %%
path = "/content/due_diligence.csv"

# %%
data = pd.read_excel("due_diligence (1).xlsx")

# %%
df0 = data[["Due Diligence Question or Request Description"]]
df = df0.rename(columns={"Due Diligence Question or Request Description":"qu"})
df = df.dropna()
#df

# %%
sentences = list(df.iloc[:, 0])

# %%
sentences_vector = model.encode(sentences)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(
    [[2.98299462e-01,  4.67688084e-01,  6.65377259e-01,
        -3.20049793e-01,  6.41659141e-01,  4.01473612e-01,
         9.65987965e-02,  3.17662835e-01, -4.54112589e-01,
        -2.90934920e-01, -1.05772860e-01,  2.12294668e-01,
        -1.70537233e-01,  4.59123015e-01, -5.39545834e-01,
        -4.67298150e-01, -1.21590912e+00,  7.71893501e-01,
        -2.80388594e-02, -8.30109298e-01,  7.95215294e-02,
        -1.87270805e-01,  4.55481261e-01,  1.91641897e-02,
        -1.68789938e-01,  1.39909312e-01, -1.49985582e-01,
        -1.62001029e-01, -3.56504411e-01, -1.19342968e-01,
        -1.63047880e-01, -7.70340145e-01,  2.55223453e-01,
        -1.39400691e-01, -1.85448766e-01, -5.20474970e-01,
         2.62281112e-02, -1.69609189e-02, -3.52809876e-02,
        -2.20502973e-01, -7.22172081e-01, -6.61695227e-02,
         1.54808253e-01,  1.44450235e+00, -1.72451898e-01,
        -3.61167490e-01, -2.88469046e-01,  5.91593146e-01,
        -1.54411197e-01,  6.53012633e-01, -7.65048087e-01,
        -1.09829903e-01,  8.12182128e-01,  3.98595445e-02,
        -7.95669973e-01,  5.68840981e-01, -1.64507166e-01,
        -2.16755450e-01, -1.36204457e+00,  2.52892613e-01,
         8.09833884e-01,  2.06680685e-01,  3.98784578e-01,
        -1.41640559e-01,  4.89197165e-01, -2.54218221e-01,
         6.42482996e-01, -2.49051422e-01, -8.64459872e-01,
        -2.07037345e-01,  4.94056404e-01, -8.76384616e-01,
        -4.56454337e-01,  7.61520028e-01, -7.56318212e-01,
         4.81516793e-02, -3.91107380e-01,  2.35586166e-01,
         3.60257566e-01, -2.85090089e-01, -1.35517627e-01,
         1.05139923e+00,  2.87309475e-02,  5.49764514e-01,
         3.88210595e-01, -3.77728641e-01,  1.42903745e-01,
        -6.79947138e-01, -5.27450681e-01,  1.02366030e-01,
         2.84000151e-02, -6.66738689e-01,  2.11962402e-01,
         5.12800366e-02,  1.92485929e-01, -1.29312515e-01,
         6.42309785e-01,  1.20370910e-02, -1.01539537e-01,
        -4.04759347e-01, -2.19018087e-01, -4.96067613e-01,
        -1.01911351e-01, -3.15831035e-01,  1.90878987e-01,
         2.08912939e-01, -3.05340797e-01, -3.09668839e-01,
        -6.29356623e-01, -4.26908851e-01, -4.07489151e-01,
        -6.18556976e-01, -7.86504596e-02, -7.76986033e-02,
        -5.48973441e-01,  9.15031910e-01,  2.16233611e-01,
         5.21463275e-01, -3.02385926e-01, -2.02542126e-01,
        -2.21469119e-01,  1.64714426e-01, -1.93209365e-01,
        -3.86774614e-02,  1.98827505e-01,  4.97480392e-01,
         1.24245435e-01, -1.44679338e-01,  7.87089705e-01,
         7.82845140e-01, -4.04372692e-01, -6.45978093e-01,
         2.90396661e-01,  6.03003167e-02,  2.01487243e-01,
         1.00575197e+00,  2.42916241e-01,  4.40299451e-01,
         8.12108591e-02,  6.03072882e-01, -6.49991453e-01,
         2.46798128e-01,  5.80117464e-01, -4.81912792e-01,
        -2.11372614e-01,  7.98573315e-01, -2.52093315e-01,
         2.05360323e-01, -3.66919577e-01, -3.91925395e-01,
        -3.30008119e-01,  4.69668716e-01,  3.98635775e-01,
         2.77729928e-01, -3.53051484e-01,  7.33897924e-01,
        -2.04158664e-01,  7.81006292e-02, -4.31555867e-01,
        -3.02328289e-01,  1.08696914e+00,  9.32248086e-02,
         6.36326373e-01,  5.99035263e-01, -1.29932031e-01,
         3.08310568e-01, -5.18297195e-01, -1.97943658e-01,
        -3.23853254e-01,  8.18998292e-02,  5.65281987e-01,
        -1.48930505e-01, -3.26610237e-01, -2.00641811e-01,
         1.15815736e-02,  2.67801613e-01,  5.94546318e-01,
        -7.32957304e-01, -6.37498736e-01, -5.02978802e-01,
        -3.41088593e-01,  2.05384746e-01,  4.60131615e-01,
        -6.25864089e-01,  2.78432518e-01,  3.84107381e-02,
        -6.40527964e-01, -6.18563533e-01, -4.41707075e-02,
        -1.39534742e-01,  7.27958977e-02,  7.57260084e-01,
        -7.03930557e-02,  2.42370576e-01, -3.39274198e-01,
        -2.87497163e-01,  1.67417631e-01,  5.29771984e-01,
         8.47636700e-01, -7.41059259e-02, -2.50161082e-01,
        -7.52382219e-01, -3.83190513e-01,  1.28187016e-01,
        -3.98503318e-02, -5.59948802e-01,  7.15742588e-01]],
    sentences_vector[1:]
)

# %%
import pandas as pd
import numpy as np

# %%
sim = pd.DataFrame({"question":df.iloc[1:,0], "similarity":similarity.ravel()})
sim
# Out:
#                                                question  similarity
# 382   Please provide an organizational chart showing...    0.635649
# 383   Please provide copies of all joint venture agr...    0.317406
# 384   Please provide the applicable governing docume...    0.439202
# 385   Please provide a list of all jurisdictions in ...    0.454176
# 386   Please provide minutes and/or resolutions for ...    0.446525
# ...                                                 ...         ...
# 7340  Customer support incident and call report data...    0.449228
# 7341  Share any documents that describe the customer...    0.510688
# 7342       Please share services and support org charts    0.592478
# 7343  Professional service productivity analysis \nI...    0.509676
# 7344  Documentation explaining product implementatio...    0.535421
#
# [6499 rows x 2 columns]

# %%
sim['similarity'].max()
# Out:
# 0.7832391858742362
